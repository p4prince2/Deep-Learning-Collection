# %% [markdown]
# ## Adam (Adaptive Moment Estimation)

# %% [markdown]
# ### It combines the strengths of Momentum and RMSProp.

# %% [markdown]
# ![image.png](attachment:f14739da-85e5-430a-8181-4a1dc1c46bc8.png)

# %% [markdown]
# ## Adam optimizer working

# %% [markdown]
# ### 1. Compute Exponentially Weighted Averages (Moments)
# ![image.png](attachment:ce900a75-44f2-46e7-8560-6e57a3efbd83.png)

# %% [markdown]
# ### Second Moment (Adaptive Learning Rate)
# ![image.png](attachment:2e1cab43-c89c-4f49-92bf-c6692f833a6c.png)

# %% [markdown]
# ### 2. Bias Correction (Very Important Step)

# %% [markdown]
# ![image.png](attachment:8e672668-1c22-4f88-8ea7-be092ddc84a1.png)

# %% [markdown]
# ### 3. Final Parameter Update Rule
# ![image.png](attachment:c0377e22-97b9-4002-81a8-7c5f8fa744a5.png)

# %% [markdown]
# #### Note :
#
# ##### Adam = Momentum + RMSProp + Bias Correction

# %% [markdown]
# Bias correction in Adam is applied at every iteration, not only at the first forward pass, because the moving averages are biased toward zero for multiple initial steps. The correction term depends on the iteration number
# 𝑡
