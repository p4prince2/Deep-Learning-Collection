# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN

# %% [markdown]
# # Create model

# %%
model = Sequential()

# %% [markdown]
# # Add layers

# %%
model.add(SimpleRNN(3, input_shape=(4, 5)))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\p4pri\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Compile (needed if you want to train later)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# # Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 3)                   │              27 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Print weights shape (input layer)

# %%
print(model.get_weights()[0].shape)
# Out:
# (5, 3)

# %% [markdown]
# # Print weights (input layer)

# %%
print(model.get_weights()[0])
# Out:
# [[-0.15575951  0.77433985 -0.26605225]
#  [ 0.35326654  0.2912174  -0.04339641]
#  [ 0.5801125  -0.32820994  0.03600496]
#  [ 0.08494258  0.44201154 -0.45021653]
#  [-0.18687385 -0.73818976 -0.01678383]]

# %% [markdown]
# # Print weights shape and Print weights (rnn self node)

# %%
print(model.get_weights()[1].shape)
# Out:
# (3, 3)

# %%
print(model.get_weights()[1])
# Out:
# [[-0.06527352 -0.9481192   0.31114176]
#  [ 0.9891593  -0.10258144 -0.10507573]
#  [-0.13154168 -0.30091012 -0.94453686]]

# %% [markdown]
# # Print weights shape and Print weights (last layer)

# %%
print(model.get_weights()[2].shape)
# Out:
# (3,)

# %%
print(model.get_weights()[2])
# Out:
# [0. 0. 0.]
